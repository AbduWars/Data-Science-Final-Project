# %%
# Data Science Final Project

## Introduction

This notebook is a final project for the Data Science course. It will cover various aspects of data science, including popular languages, libraries, tools, and examples of arithmetic operations. The notebook is structured to demonstrate the essential skills required for a data scientist.


## Data Science Languages

Here are some of the most popular languages used in data science:

1. Python
2. R
3. SQL
4. Julia
5. Scala


## Data Science Libraries

Some commonly used libraries in data science include:

1. Pandas
2. NumPy
3. Matplotlib
4. SciPy
5. scikit-learn
6. TensorFlow
7. Keras
8. PyTorch


## Data Science Tools

| Tool            | Description                                        |
|-----------------|----------------------------------------------------|
| Jupyter Notebook| An open-source web application to create and share documents that contain live code, equations, visualizations, and narrative text. |
| RStudio         | An integrated development environment (IDE) for R. |
| Apache Hadoop   | A framework for distributed storage and processing of large data sets. |
| Tableau         | A data visualization tool used for converting raw data into an understandable format. |
| Power BI        | A business analytics service by Microsoft.         |


## Arithmetic Expression Examples

In this section, we will demonstrate simple arithmetic operations such as addition and multiplication using Python code.


# Function to convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example conversion
minutes = 120
hours = minutes_to_hours(minutes)
hours


## Objectives

The main objectives of this notebook are:

1. To list and describe popular data science languages and libraries.
2. To provide examples of data science tools.
3. To demonstrate basic arithmetic operations in Python.
4. To convert time units from minutes to hours using Python code.


## Author

Name: [Abdurahman Warsama]
